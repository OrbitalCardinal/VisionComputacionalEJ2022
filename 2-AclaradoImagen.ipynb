# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Libreria propia 
# %run vislib.py

# %%
# Abrir imagen
path = 'arte.jpeg'
img_bgr2 = cv2.imread("./arte.jpeg")
img_rgb = cv2.cvtColor(img_bgr2, cv2.COLOR_BGR2RGB)
img_gray = escala_grises(img_rgb)

# %%
show_img(img_gray)

# %%
# ACLARAR IMAGEN
dim = img_gray.shape
for i in range(dim[0]):
    for j in range(dim[1]):
        img_gray[i,j] = img_gray[i,j] + 60

# %%
show_img(img_gray)
