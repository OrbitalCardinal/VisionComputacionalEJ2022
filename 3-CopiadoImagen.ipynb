# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %run vislib.py

# %%
path = 'arte.jpeg'
img = open_img(path)
img_gray = gray_scale(img)

# %%
show_img(img_gray)

# %%
dim = img_gray.shape
img2 = np.zeros((dim[0], dim[1]))

# %%
for i in range(dim[0]):
    for j in range(dim[1]):
        img2[i,j] = img_gray[i,j]

# %%
show_img(img2)
