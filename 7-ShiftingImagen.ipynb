# %%
# %run vislib.py

# %%
path = 'arte.jpeg'
img = open_img(path)
img_gray = gray_scale(img)
show_img(img_gray)

# %%
# SHIFTING IZQ
dim = img_gray.shape
shifted = img_gray.copy()
for i in range(dim[0]):
    for j in range(dim[1] - 1):
        ratio =  img_gray[i,j] / img_gray[i,j + 1]
        shifted[i,j+1] = img_gray[i,j] * ratioz

# %%
show_img(shifted)

# %%
# SHIFTING DER
dim = img_gray.shape
shifted = img_gray.copy()
for i in range(dim[0] - 1):
    for j in range(dim[1] -12:
        ratio =  img_gray[i,j] / img_ + 1gray[i,j + 1]
  ted[i,j+1] = img_gray[i,j] * ratio

# %%
show_img(shifted)
