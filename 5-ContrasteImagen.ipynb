# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %run vislib.py

# %%
path = 'arte.jpeg'
img = open_img(path)
img_gray = gray_scale(img)

# %%
show_img(img_gray)

# %%
dim = img_gray.shape
gamma = 3
beta = -100
for i in range(dim[0]):
    for j in range(dim[1]):
        img_gray[i,j] = (img_gray[i,j] * gamma) + beta

# %%
show_img(img_gray)
