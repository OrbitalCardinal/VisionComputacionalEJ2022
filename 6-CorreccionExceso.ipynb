# %%
# %run vislib.py

# %%
path = 'arte.jpeg'
img = open_img(path)
img_gray = gray_scale(img)
show_img(img_gray)

# %%
img_bright = increase_brightness(img_gray , beta = 90, correct= True)
show_img(img_bright)
